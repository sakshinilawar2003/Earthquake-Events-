# %% [markdown]
# ### **02 Worldwide Earthquake Events API - Silver Layer Processing**

# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
from pyspark.sql.functions import col
from pyspark.sql.types import TimestampType
# Out:
# StatementMeta(, 30d52942-ab0d-438d-a952-12fcbde3a503, 3, Finished, Available, Finished)

# %%
#from datetime import date , timedelta

#start_date = date.today()- timedelta(7)
#print(start_date)

# %%
# df now is a Spark DataFrame containing JSON data
df = spark.read.option("multiline", "true").json(f"Files/{start_date}_earthquake_data.json")
# Out:
# StatementMeta(, 30d52942-ab0d-438d-a952-12fcbde3a503, 10, Finished, Available, Finished)

# %%
display(df)
# Out:
# StatementMeta(, 30d52942-ab0d-438d-a952-12fcbde3a503, 11, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 30e88f3c-c88c-45a0-a2ed-212f30f5546e)

# %%
#display(df.select(col('geometry.coordinates').getItem(0)))
display(df.select(col('properties.mag')))
# Out:
# StatementMeta(, 30d52942-ab0d-438d-a952-12fcbde3a503, 15, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, e866eada-e0a8-463b-964b-fa228eba0e46)

# %%
# Reshape earthquake data by extracting and renaming key attributes for further analysis.
df = \
df.\
    select(
        'id',
        col('geometry.coordinates').getItem(0).alias('longitude'),
        col('geometry.coordinates').getItem(1).alias('latitude'),
        col('geometry.coordinates').getItem(2).alias('elevation'),
        col('properties.title').alias('title'),
        col('properties.place').alias('place_description'),
        col('properties.sig').alias('sig'),
        col('properties.mag').alias('mag'),
        col('properties.magType').alias('magType'),
        col('properties.time').alias('time'),
        col('properties.updated').alias('updated')
        )
# Out:
# StatementMeta(, 30d52942-ab0d-438d-a952-12fcbde3a503, 16, Finished, Available, Finished)

# %%
# Convert 'time' and 'updated' columns from milliseconds to timestamp format for clearer datetime representation.
df = df.\
    withColumn('time', col('time')/1000).\
    withColumn('updated', col('updated')/1000).\
    withColumn('time', col('time').cast(TimestampType())).\
    withColumn('updated', col('updated').cast(TimestampType()))
# Out:
# StatementMeta(, 30d52942-ab0d-438d-a952-12fcbde3a503, 17, Finished, Available, Finished)

# %%
display(df)
# Out:
# StatementMeta(, 30d52942-ab0d-438d-a952-12fcbde3a503, 18, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 76e8de2d-4e06-46e2-9122-3a23c71f5a54)

# %%
# appending the data to the gold table
df.write.mode('append').saveAsTable('earthquake_events_silver')
# Out:
# StatementMeta(, 30d52942-ab0d-438d-a952-12fcbde3a503, 20, Finished, Available, Finished)
